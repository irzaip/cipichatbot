# %%
#buat remove file yang kira-kira duplikat. dan mirip... supaya gak banyak yang dobel.

# %%
import re
import os
import glob

# %%
a = glob.glob('../*/*/*.zip')

# %%
a[83].split("-")
# Out:
# ['..\\data\\subscene\\bilal',
#  'a',
#  'new',
#  'breed',
#  'of',
#  'hero_indonesian',
#  '1763064.zip']

# %%
for i in range(len(a)):
    nx = a[i].split("-")
    pv = a[i-1].split("-")
    if nx[0:2]==pv[0:2]:
        print(a[i])
        os.remove(a[i])

# %%
# Out:
# ['..\\data\\subscene\\1-night-2-days-tv_indonesian-1765517.zip',
#  '..\\data\\subscene\\10x10_indonesian-1759368.zip',
#  '..\\data\\subscene\\12-strong_indonesian-1758356.zip',
#  '..\\data\\subscene\\13-reasons-why-second-season_indonesian-1778270.zip',
#  '..\\data\\subscene\\15-iq-krachoot_indonesian-1765278.zip',
#  '..\\data\\subscene\\3-2018_indonesian-1772554.zip',
#  '..\\data\\subscene\\300-rise-of-an-empire_indonesian-1778510.zip',
#  '..\\data\\subscene\\3000-miles-to-graceland_indonesian-1764585.zip',
#  '..\\data\\subscene\\8mm_indonesian-1757974.zip',
#  '..\\data\\subscene\\9-1-1-first-season_indonesian-1778431.zip',
#  '..\\data\\subscene\\a-better-tomorrow-ying-hung-boon-sik-1986_indonesian-1763462.zip',
#  '..\\data\\subscene\\a-fantastic-woman_indonesian-1767050.zip',
#  '..\\data\\subscene\\a-gentleman_indonesian-1776919.zip',
#  '..\\data\\subscene\\a-poem-a-day-you-who-forgot-poetry-shireul-izeun-geudaee_HI_indonesian-1757814.zip',
# ...
