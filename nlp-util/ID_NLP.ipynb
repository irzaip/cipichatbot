# %%
#!pip install rasa_nlu[spacy]
#https://rasahq.github.io/rasa-nlu-trainer/

# %%
from rasa_nlu.training_data import load_data
from rasa_nlu.config import RasaNLUModelConfig
from rasa_nlu.model import Trainer
from rasa_nlu import config

training_data = load_data('basic-chippy.json')
trainer = Trainer(config.load("config_spacy.yml"))
trainer.train(training_data)
model_directory = trainer.persist('./')  # Returns the directory the model is stored in
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-ce922c0666ce> in <module>()
# ----> 1 from rasa_nlu.training_data import load_data
#       2 from rasa_nlu.config import RasaNLUModelConfig
#       3 from rasa_nlu.model import Trainer
#       4 from rasa_nlu import config
#       5
#
# ModuleNotFoundError: No module named 'rasa_nlu'

# %%
from rasa_nlu.model import Metadata, Interpreter

# where `model_directory points to the folder the model is persisted in
interpreter = Interpreter.load(model_directory)

# %%
a = interpreter.parse(u"show me italian cuisine near indonesia")

# %%
a
# Out:
# {'intent': {'name': 'greet', 'confidence': 0.40793451769455646},
#  'entities': [],
#  'intent_ranking': [{'name': 'greet', 'confidence': 0.40793451769455646},
#   {'name': 'affirm', 'confidence': 0.28585908672175303},
#   {'name': 'goodbye', 'confidence': 0.19689503715892523},
#   {'name': 'restaurant_search', 'confidence': 0.10931135842476541}],
#  'text': 'good morning'}

# %%
import spacy

# Load English tokenizer, tagger, parser, NER and word vectors
nlp = spacy.load('xx')

# Process whole documents
text = (u"Waktu itu saya suka makan bakso, padahal hari sudah pagi, kenapa ada hal seperti itu?")
doc = nlp(text)

# Find named entities, phrases and concepts
for entity in doc.ents:
    print(entity.text, entity.label_)

# Determine semantic similarities
doc1 = nlp(u"Apakah saya suka")
doc2 = nlp(u"kondor biji")
similarity = doc1.similarity(doc2)
print(doc1.text, doc2.text, similarity)
# Out:
# Waktu PER
# Apakah saya suka kondor biji 0.7131739997293696

# %%
import nltk

# %%
from nltk.corpus import stopwords

# %%
stopwords.words('indonesian')
# Out:
# ['ada',
#  'adalah',
#  'adanya',
#  'adapun',
#  'agak',
#  'agaknya',
#  'agar',
#  'akan',
#  'akankah',
#  'akhir',
#  'akhiri',
#  'akhirnya',
#  'aku',
#  'akulah',
#  'amat',
#  'amatlah',
#  'anda',
#  'andalah',
#  'antar',
#  'antara',
#  'antaranya',
#  'apa',
#  'apaan',
#  'apabila',
#  'apakah',
#  'apalagi',
#  'apatah',
#  'artinya',
#  'asal',
#  'asalkan',
#  'atas',
#  'atau',
#  'ataukah',
#  'ataupun',
#  'awal',
#  'awalnya',
#  'bagai',
#  'bagaikan',
#  'bagaimana',
#  'bagaimanakah',
#  'bagaimanapun',
#  'bagi',
#  'bagian',
#  'bahkan',
#  'bahwa',
#  'bahwasanya',
#  'baik',
#  'bakal',
#  'bakalan',
#  'balik',
#  'banyak',
#  'bapak',
#  'baru',
#  'bawah',
#  'beberapa',
#  'begini',
#  'beginian',
#  'beginikah',
#  'beginilah',
#  'begitu',
#  'begitukah',
#  'begitulah',
#  'begitupun',
#  'bekerja',
#  'belakang',
#  'belakangan',
#  'belum',
#  'belumlah',
#  'benar',
#  'benarkah',
#  'benarlah',
#  'berada',
#  'berakhir',
#  'berakhirlah',
# ...

# %%
len(stopwords.words("english"))
# Out:
# 179

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
factory = StemmerFactory()
stemmer = factory.create_stemmer()

kalimat = 'lihat gambar anak kecil'
katadasar = stemmer.stem(kalimat)

print(katadasar)
# Out:
# lihat gambar anak kecil

# %%
import nltk
from nltk.tag import CRFTagger
ct = CRFTagger()
ct.set_model_file('all_indo_man_tag_corpus_model.crf.tagger')
kalimat = 'Berikan saya minum'

tagg=nltk.word_tokenize(kalimat)
hasil = ct.tag_sents([tagg])
print(hasil)
# Out:
# [[('Berikan', 'VB'), ('saya', 'PRP'), ('minum', 'NEG')]]

# %%
from rasa_core.agent import Agent

# %%
#agent = Agent.load("examples/restaurantbot/models/dialogue", interpreter="examples/restaurantbot/models/nlu/current")
Agent.load_data("../rasa_core/examples/restaurantbot/data/franken_data.json","../rasa_core/examples/restaurantbot/restaurant_domain.yml")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-4b2aeead5caa> in <module>()
#       1 #agent = Agent.load("examples/restaurantbot/models/dialogue", interpreter="examples/restaurantbot/models/nlu/current")
# ----> 2 Agent.load_data("../rasa_core/examples/restaurantbot/data/franken_data.json","../rasa_core/examples/restaurantbot/restaurant_domain.yml")
#
# C:\Anaconda3\envs\tensorflow\lib\site-packages\rasa_core\agent.py in load_data(self, resource_name, remove_duplicates, augmentation_factor, max_number_of_trackers, tracker_limit, use_story_concatenation)
#     184         """Load training data from a resource."""
#     185
# --> 186         return training.load_data(resource_name, self.domain, remove_duplicates,
#     187                                   augmentation_factor, max_number_of_trackers,
# ...
