# %%
fgh = '../data/textdata/dialog_kecil.txt'

# %%
with open(fgh,"r") as f:
    txt = f.readlines()

# %%
ff = []
for i,tx in enumerate(txt):
    if tx[0] == 'A':
        ff.append(tx)
    if tx[0] == "B":
        ff.append(tx)
        ff.append("\n")

# %%
with open(fg)
# Out:
# ['A: Saya tidak mengerti beberapa hal.\n',
#  'B: Biarkan saya membantu Anda.\n',
#  '\n',
#  'A: Apa artinya "MI"?\n',
#  'B: "MI" adalah singkatan dari Middle Initial.\n',
#  '\n',
#  'A: Apa artinya "MM / DD / YY"?\n',
#  'B: Itu berarti Bulan / Hari / Tahun. Gunakan angka.\n',
#  '\n',
#  'A: Saya tidak mengerti.\n',
#  'B: Misalnya, jika tanggal lahir Anda adalah 12 Januari 1987, tulis 01/12/87.\n',
#  '\n',
#  'A: Oh. Itu cukup sederhana.\n',
#  'B: Selalu cetak dengan jelas, dan isi gelembung sepenuhnya.\n',
#  '\n',
#  'A: Mari pergi ke penampungan hewan.\n',
#  'B: Apa yang ingin kamu lakukan?\n',
#  '\n',
#  'A: Saya ingin mendapatkan anak anjing untuk anak saya.\n',
#  'B: Itu akan membuatnya sangat bahagia.\n',
#  '\n',
#  'A: Saya akan memberinya salah satu anjing kecil itu.\n',
#  'B: Satu yang tidak akan tumbuh terlalu besar.\n',
#  '\n',
#  'A: Dan makan terlalu banyak.\n',
#  'B: Apakah kamu tahu yang mana yang dia suka?\n',
#  '\n',
# ...
